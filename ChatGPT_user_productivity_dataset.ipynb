# %% [markdown]
# <a href="https://colab.research.google.com/github/Smriti-Prajapati/ChatGPT-user-productivity-analysis/blob/main/ChatGPT_user_productivity_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('chatgpt_user_productivity_dataset_300.csv',
                 encoding='latin1',
                 on_bad_lines='skip',
                 engine='python')
df.head()
# Out:
#   User_ID  Age  Gender Profession  Daily_Usage_Hours   Purpose  \
# 0      U1   25    Male   Engineer                  4    Coding
# 1      U2   24   Other    Student                  4  Learning
# 2      U3   31    Male    Student                  2  Research
# 3      U4   35    Male    Teacher                  5   Writing
# 4      U5   31  Female    Student                  1  Research
#
#    Sessions_Per_Day  Avg_Response_Rating Productivity_Level
# 0                 4                    5             Medium
# 1                 4                    3             Medium
# 2                 2                    4                Low
# 3                 6                    3             Medium
# 4                 1                    4                Low

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   User_ID              300 non-null    object
#  1   Age                  300 non-null    int64
#  2   Gender               300 non-null    object
#  3   Profession           300 non-null    object
#  4   Daily_Usage_Hours    300 non-null    int64
#  5   Purpose              300 non-null    object
#  6   Sessions_Per_Day     300 non-null    int64
#  7   Avg_Response_Rating  300 non-null    int64
#  8   Productivity_Level   300 non-null    object
# dtypes: int64(4), object(5)
# memory usage: 21.2+ KB

# %%
df.describe()
# Out:
#               Age  Daily_Usage_Hours  Sessions_Per_Day  Avg_Response_Rating
# count  300.000000         300.000000        300.000000           300.000000
# mean    34.153333           4.170000          5.163333             4.110000
# std      9.230049           1.682419          1.887290             0.804191
# min     18.000000           1.000000          1.000000             3.000000
# 25%     26.000000           3.000000          4.000000             3.000000
# 50%     35.000000           4.000000          5.000000             4.000000
# 75%     42.000000           5.000000          6.250000             5.000000
# max     50.000000           7.000000          9.000000             5.000000

# %%
plt.hist(df['Age'], bins=10)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
sns.boxplot(x=df['Daily_Usage_Hours'])
plt.title('Daily Usage Hours')
plt.show()

# %%
df['Profession'].value_counts().plot(kind='bar')
plt.title('Profession Distribution')
plt.xlabel('Profession')
plt.ylabel('Count')
plt.show()

# %%
plt.scatter(df['Age'], df['Daily_Usage_Hours'])
plt.xlabel('Age')
plt.ylabel('Daily Usage Hours')
plt.title('Age vs Daily Usage')
plt.show()

# %%
sns.boxplot(x='Gender', y='Daily_Usage_Hours', data=df)
plt.title('Gender vs Daily Usage')
plt.show()

# %%
pd.crosstab(df['Profession'], df['Gender']).plot(kind='bar')
plt.title('Profession vs Gender')
plt.xlabel('Profession')
plt.ylabel('Count')
plt.show()

# %%
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True)
plt.title('Correlation Heatmap')
plt.show()

# %%
sns.pairplot(df)
plt.show()
